# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_hdf('compressed_Y1A1_GOLD101_Y1A1trainValid_14.12.2015.validsY1A1.25215.out.DES.pdf.hdf5', 'pdf1')

# %%
print data.shape
# Out:
# (10000, 4)

# %%
data = pd.read_hdf('compressed_Y1A1_GOLD101_Y1A1trainValid_14.12.2015.validsY1A1.25215.out.DES.pdf.hdf5', 'pdf2')

# %%
print data
# Out:
#       COADD_OBJECTS_ID                                     PDF_compressed  \
# 0           3162617133  [0.64795, 1.499, 2.332, 2.4238, 1.6475, 0.6645...
# 1           3162634734  [2.0137, 2.584, 2.166, 1.1621, 0.39771, 0.0732...
# 2           3162636666  [0.065247, 0.24158, 0.66748, 1.373, 2.0332, 2....
# 3           3162266147  [0.0024757, 0.018738, 0.1026, 0.39087, 1.0957,...
# 4           3162705941  [0.16565, 0.82373, 2.2148, 3.1602, 2.2988, 0.7...
# 5           3162274860  [0.31567, 0.88135, 1.7236, 2.3496, 2.1797, 1.2...
# 6           3162837803  [0.59375, 1.5371, 2.5137, 2.5742, 1.6084, 0.54...
# 7           3162255779  [0.18689, 0.76025, 1.8818, 2.8008, 2.418, 1.10...
# 8           3162637128  [0.083435, 0.29419, 0.771, 1.5029, 2.1074, 2.0...
# 9           3162649625  [0.0010576, 0.010681, 0.074036, 0.33838, 1.083...
# 10          3162712044  [0.0012541, 0.0085602, 0.045105, 0.18176, 0.53...
# 11          3162748932  [0.0078278, 0.050903, 0.23425, 0.75293, 1.626,...
# ...

# %%
data = pd.read_hdf('compressed_Y1A1_GOLD101_Y1A1trainValid_14.12.2015.validsY1A1.25215.out.DES.pdf.hdf5', 'pdf3')

# %%
print data.shape
# Out:
# (10000, 4)

# %%
data_rec = pd.read_hdf('compressed_Y1A1_GOLD101_Y1A1trainValid_14.12.2015.validsY1A1.25215.out.DES.pdf.hdf5reconstructed')

# %%
data_rec.shape
# Out:
# (48042, 30)
